# %% [markdown]
# # DLC Installation on AppStream (Windows)
#
# This report instructs how to build a Windows image with DeepLabCut installed. Please follow the [Sleap-Windows-Report](./Sleap-Windows-Report.ipynb) for instructions on installing Sleap on Windows Image as well as a more detailed guide through the image building process for Windows.
#
# - [Windows Build Image Instruction](#Windows-Build-Image-Instruction)
#     - [Lauch GUI by default](#Launch-GUI-by-default)

# %% [markdown]
# ## Windows Build Image Instruction
#
# See [Image Builder Guide](./AppStream-Image-Builder-Guide.md) for an overview and explanation of each step, or see [Sleap image notebook](./Windows-Conda-Sleap-Image.ipynb) for a more detailed run through each step.
#
# ### Admin User Install Package Step
#
#     # In gitbash
#     git clone https://github.com/DeepLabCut/DeepLabCut.git
#
#     # In Anaconda prompt
#     cd DeepLabCut\conda-environments
#     conda env create -f DEEPLABCUT.yaml
#
#
# ### Template User Default Settings Step
#
#
# **Configure DLC:** Launch DeepLabCut once to let it set up some configuration files (e.g. `.keras`, `.matplotlib`).
#
#     (base) conda activate DEEPLABCUT
#     (DEEPLABCUT) python -m deeplabcut
#
#
# ### Test User Testing Step
#
# Run the testscript provided by the DeepLabCut GitHub repo and make sure it runs without errors. You may also verify that the DeepLabCut GUI launches successfully.
#
#     # In gitbash
#     git clone https://github.com/DeepLabCut/DeepLabCut.git
#
#     # In Anaconda prompt
#     (base) conda activate DEEPLABCUT
#     (DEEPLABCUT) cd C:\Users\ImageBuilderTest\DeepLabCut
#     (DEEPLABCUT) python testscript_cli.py
#
#     (DEEPLABCUT) python -m deeplabcut
#
# ### Admin User Optimization Step
#
# (Not sure if this step actually helps improve user instance launch speed) Launch the DeepLabCut GUI so that AppStream can capture the files it needs to optimize.
#
#     (base) conda activate DEEPLABCUT
#     (DEEPLABCUT) python -m deeplabcut

# %% [markdown]
# ## Configure to Launch GUI by default
#
# If you would like to have the DEEPLABCUT conda enviornment activated by default so users don't have to activate themselves, you can re-configure the terminal app launch parameters as shown in the following diagram. Remember that `C:\Users\ImageBuilderAdmin\AppData\Roaming\Microsoft\Windows\Start Menu\Programs\Miniconda3 (64-bit)` is the shortcut to the Anaconda prompt app, as demonstrated in the [Sleap image notebook](./Windows-Conda-Sleap-Image.ipynb)
#
# ![dlc-terminal-appconfig.png](attachment:dlc-terminal-appconfig.png)

# %% [markdown]
# If you would like to the appto launch the GUI directly so users don't even have to type `python -m deeplabcut` themselves, you can also incorporate that into the app launch parameters, as shown in the following figure.
#
# ![dlc-gui-terminal-appconfig.png](attachment:dlc-gui-terminal-appconfig.png)
#
# **Tip** If during the testing phase or optimization phase, the terminal is trying to load the GUI but nothing shows up, try pressing enter on the keyboad, and the loading messages should appear.
